# %% [markdown]
# # Set-up

# %%
pip install kaggle

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import RepeatedKFold, cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFE
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Import Data from Kaggle API

# %%
raw_data = pd.read_csv('Listings.csv',encoding='ISO-8859-1' ,dtype={5: str, 13: str})

# %%
raw_data.head(5)
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                   39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#    host_since                 host_location host_response_time  \
# 0  2011-12-03  Paris, Ile-de-France, France                NaN
# 1  2013-11-29  Paris, Ile-de-France, France                NaN
# 2  2014-07-31  Paris, Ile-de-France, France                NaN
# 3  2013-12-17  Paris, Ile-de-France, France                NaN
# 4  2014-12-14  Paris, Ile-de-France, France                NaN
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 NaN                   NaN                 f
# 1                 NaN                   NaN                 f
# 2                 NaN                   NaN                 f
# 3                 NaN                   NaN                 f
# 4                 NaN                   NaN                 f
#
#    host_total_listings_count  ... minimum_nights maximum_nights  \
# 0                        1.0  ...              2           1125
# 1                        1.0  ...              2           1125
# 2                        1.0  ...              2           1125
# 3                        1.0  ...              2           1125
# 4                        1.0  ...              2           1125
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                100.0                   10.0                      10.0
# 1                100.0                   10.0                      10.0
# 2                100.0                   10.0                      10.0
# 3                100.0                   10.0                      10.0
# 4                100.0                   10.0                      10.0
#
#    review_scores_checkin  review_scores_communication review_scores_location  \
# 0                   10.0                         10.0                   10.0
# 1                   10.0                         10.0                   10.0
# 2                   10.0                         10.0                   10.0
# 3                   10.0                         10.0                   10.0
# 4                   10.0                         10.0                   10.0
#
#   review_scores_value  instant_bookable
# 0                10.0                 f
# 1                10.0                 f
# 2                10.0                 f
# 3                10.0                 f
# 4                10.0                 f
#
# [5 rows x 33 columns]

# %% [markdown]
# # Data Analysis, Data Clean and Data Preprocessing

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279712 entries, 0 to 279711
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   listing_id                   279712 non-null  int64
#  1   name                         279539 non-null  object
#  2   host_id                      279712 non-null  int64
#  3   host_since                   279547 non-null  object
#  4   host_location                278872 non-null  object
#  5   host_response_time           150930 non-null  object
#  6   host_response_rate           150930 non-null  float64
#  7   host_acceptance_rate         166625 non-null  float64
#  8   host_is_superhost            279547 non-null  object
#  9   host_total_listings_count    279547 non-null  float64
#  10  host_has_profile_pic         279547 non-null  object
#  11  host_identity_verified       279547 non-null  object
#  12  neighbourhood                279712 non-null  object
#  13  district                     37012 non-null   object
#  14  city                         279712 non-null  object
#  15  latitude                     279712 non-null  float64
#  16  longitude                    279712 non-null  float64
#  17  property_type                279712 non-null  object
#  18  room_type                    279712 non-null  object
#  19  accommodates                 279712 non-null  int64
#  20  bedrooms                     250277 non-null  float64
#  21  amenities                    279712 non-null  object
#  22  price                        279712 non-null  int64
#  23  minimum_nights               279712 non-null  int64
#  24  maximum_nights               279712 non-null  int64
#  25  review_scores_rating         188307 non-null  float64
#  26  review_scores_accuracy       187999 non-null  float64
#  27  review_scores_cleanliness    188047 non-null  float64
#  28  review_scores_checkin        187941 non-null  float64
#  29  review_scores_communication  188025 non-null  float64
#  30  review_scores_location       187937 non-null  float64
#  31  review_scores_value          187927 non-null  float64
#  32  instant_bookable             279712 non-null  object
# dtypes: float64(13), int64(6), object(14)
# memory usage: 70.4+ MB

# %% [markdown]
# ## 考虑设置价格作为因变量，将其他特征作为协变量，使用机器学习算法根据特征对价格进行预测

# %% [markdown]
# ## 删除无用列

# %%
raw_data['district'].value_counts()
# 由于该变量缺失值过多，难以进行补充，并且对预测效果帮助不大，因此删去
# Out:
# Manhattan        16545
# Brooklyn         14468
# Queens            4700
# Bronx              992
# Staten Island      289
# Name: district, dtype: int64

# %%
#id对价格不会产生影响，同样删除，
drop_var = ['listing_id', 'host_id', 'district']
raw_data.drop(columns=drop_var, inplace = True)

# %%
raw_data.head(5)
#列数由33变为30
# Out:
#                                                name  host_since  \
# 0    Beautiful Flat in le Village Montmartre, Paris  2011-12-03
# 1                   39 mÃÂ² Paris (Sacre CÃ
# âur)  2013-11-29
# 2               Lovely apartment with Terrace, 60m2  2014-07-31
# 3               Cosy studio (close to Eiffel tower)  2013-12-17
# 4  Close to Eiffel Tower - Beautiful flat : 2 rooms  2014-12-14
#
#                   host_location host_response_time  host_response_rate  \
# 0  Paris, Ile-de-France, France                NaN                 NaN
# 1  Paris, Ile-de-France, France                NaN                 NaN
# 2  Paris, Ile-de-France, France                NaN                 NaN
# 3  Paris, Ile-de-France, France                NaN                 NaN
# 4  Paris, Ile-de-France, France                NaN                 NaN
#
#    host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 0                   NaN                 f                        1.0
# 1                   NaN                 f                        1.0
# 2                   NaN                 f                        1.0
# 3                   NaN                 f                        1.0
# 4                   NaN                 f                        1.0
#
#   host_has_profile_pic host_identity_verified  ... minimum_nights  \
# 0                    t                      f  ...              2
# 1                    t                      t  ...              2
# 2                    t                      f  ...              2
# 3                    t                      t  ...              2
# 4                    t                      f  ...              2
#
#   maximum_nights  review_scores_rating  review_scores_accuracy  \
# 0           1125                 100.0                    10.0
# 1           1125                 100.0                    10.0
# 2           1125                 100.0                    10.0
# 3           1125                 100.0                    10.0
# 4           1125                 100.0                    10.0
#
#   review_scores_cleanliness review_scores_checkin  \
# 0                      10.0                  10.0
# 1                      10.0                  10.0
# 2                      10.0                  10.0
# 3                      10.0                  10.0
# 4                      10.0                  10.0
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         10.0                    10.0                10.0
# 1                         10.0                    10.0                10.0
# 2                         10.0                    10.0                10.0
# 3                         10.0                    10.0                10.0
# 4                         10.0                    10.0                10.0
#
#    instant_bookable
# 0                 f
# 1                 f
# 2                 f
# 3                 f
# 4                 f
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 剔除缺失值与类型转化

# %%
#得到将转化的二值变量
dummy_var=['host_is_superhost','host_has_profile_pic','host_identity_verified','instant_bookable']
for element in dummy_var:
    raw_data=raw_data[raw_data[element].isnull() == False]
#剔除缺失值
# Out:
# array(['f', 't', nan], dtype=object)

# %%
#进行类型转化
for element in dummy_var:    
    #raw_data2[element] = raw_data[element].astype(str)
    raw_data[element] = raw_data[element].map({'t':1,'f':0})
    raw_data[element].astype('int32')

# %%
for element in dummy_var:  
    print(raw_data[element].unique())
#剔除成功
# Out:
# [0 1]
# [1 0]
# [0 1]
# [0 1]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 279547 entries, 0 to 279711
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   name                         279375 non-null  object
#  1   host_since                   279547 non-null  object
#  2   host_location                278872 non-null  object
#  3   host_response_time           150930 non-null  object
#  4   host_response_rate           150930 non-null  float64
#  5   host_acceptance_rate         166625 non-null  float64
#  6   host_is_superhost            279547 non-null  int64
#  7   host_total_listings_count    279547 non-null  float64
#  8   host_has_profile_pic         279547 non-null  int64
#  9   host_identity_verified       279547 non-null  int64
#  10  neighbourhood                279547 non-null  object
#  11  city                         279547 non-null  object
#  12  latitude                     279547 non-null  float64
#  13  longitude                    279547 non-null  float64
#  14  property_type                279547 non-null  object
#  15  room_type                    279547 non-null  object
#  16  accommodates                 279547 non-null  int64
#  17  bedrooms                     250132 non-null  float64
#  18  amenities                    279547 non-null  object
#  19  price                        279547 non-null  int64
#  20  minimum_nights               279547 non-null  int64
#  21  maximum_nights               279547 non-null  int64
#  22  review_scores_rating         188199 non-null  float64
#  23  review_scores_accuracy       187891 non-null  float64
#  24  review_scores_cleanliness    187939 non-null  float64
#  25  review_scores_checkin        187833 non-null  float64
#  26  review_scores_communication  187917 non-null  float64
#  27  review_scores_location       187829 non-null  float64
#  28  review_scores_value          187819 non-null  float64
#  29  instant_bookable             279547 non-null  int64
# dtypes: float64(13), int64(8), object(9)
# memory usage: 74.2+ MB

# %%
#  根据汇率,将价格统一转换为人民币计价
ex_rate = {"Paris": 7.57, 
           "New York": 6.84,
           "Sydney": 4.63, 
           "Rome": 7.57,
           "Rio de Janeiro": 1.38,
           "Istanbul": 0.35,
           "Mexico City": 0.37,
           "Bangkok": 0.20,
           "Cape Town": 0.38, 
           "Hong Kong": 0.87}
city_copy = raw_data['city']
raw_data['price_CNY'] = city_copy.map(ex_rate) * raw_data['price']

# %%
# 检查是否有无重复值
raw_data[raw_data.duplicated() == True]
# Out:
#                                                      name  host_since  \
# 66632             Moderno depto con excelentes amenidades  2020-09-21
# 103516     Triple room nicely located  beside Sultanahmet  2017-01-10
# 103532     Family room nicely located  beside Sultanahmet  2017-01-10
# 103533     Triple room nicely located  beside Sultanahmet  2017-01-10
# 104081     Double room nicely located  beside Sultanahmet  2017-01-10
# 142106  Jaba Suit BeÃ
# Å¸iktaÃ
# Å¸'ta  25mÃÂ² Konforlu ...  2020-10-21
# 142108  Jaba Suit BeÃ
# Å¸iktaÃ
# Å¸'ta  25mÃÂ² Konforlu ...  2020-10-21
# 150465         Regolo Rooms Vaticano - Deluxe Double Room  2019-08-22
# 150467                  Regolo Rooms Vaticano - Twin Room  2019-08-22
# 150548           Room close from the "Champs Ãâ°lysees"  2020-03-10
# 150549           Room close from the "Champs Ãâ°lysees"  2020-03-10
# 150550           Room close from the "Champs Ãâ°lysees"  2020-03-10
# 150552  Charming room close from "Le Jardin du Luxembo...  2020-03-09
# 151313       Room in the center of Saint Germain District  2020-03-10
# 158933             Boutique Hotel in Old City Sultanahmet  2016-11-12
# 164064                                   The New National  2019-10-25
# 164616              Doppia/letti singoli Target Inn Hotel  2013-03-01
# 164617              Doppia/letti singoli Target Inn Hotel  2013-03-01
# 164618              Doppia/letti singoli Target Inn Hotel  2013-03-01
# 166634             Boutique Hotel in Old City Sultanahmet  2016-11-12
# 166635             Boutique Hotel in Old City Sultanahmet  2016-11-12
# 173793         Well-kept apartment home | 1BR in New York  2020-09-23
# 173807         Well-kept apartment home | 1BR in New York  2020-09-23
# 173812         Well-kept apartment home | 1BR in New York  2020-09-23
# 173817         Well-kept apartment home | 1BR in New York  2020-09-23
# 202196         Well-kept apartment home | 2BR in New York  2020-09-23
# 203497               Spectacular Apt | Studio in Brooklyn  2020-07-29
#
#                            host_location host_response_time  \
# 66632   Mexico City, Mexico City, Mexico     within an hour
# 103516                                TR     within an hour
# 103532                                TR     within an hour
# 103533                                TR     within an hour
# 104081                                TR     within an hour
# 142106  BeÃ
# Å¸iktaÃ
# Å¸, Istanbul, Turkey     within an hour
# 142108  BeÃ
# Å¸iktaÃ
# Å¸, Istanbul, Turkey     within an hour
# 150465                                IT                NaN
# 150467                                IT                NaN
# 150548      Paris, Ile-de-France, France                NaN
# 150549      Paris, Ile-de-France, France                NaN
# 150550      Paris, Ile-de-France, France                NaN
# 150552      Paris, Ile-de-France, France                NaN
# 151313      Paris, Ile-de-France, France                NaN
# 158933        Istanbul, Istanbul, Turkey     within an hour
# 164064                                ZA                NaN
# 164616                Rome, Lazio, Italy                NaN
# 164617                Rome, Lazio, Italy                NaN
# 164618                Rome, Lazio, Italy                NaN
# 166634        Istanbul, Istanbul, Turkey     within an hour
# 166635        Istanbul, Istanbul, Turkey     within an hour
# 173793     Houston, Texas, United States     within an hour
# 173807     Houston, Texas, United States     within an hour
# 173812     Houston, Texas, United States     within an hour
# 173817     Houston, Texas, United States     within an hour
# 202196     Houston, Texas, United States     within an hour
# 203497     Houston, Texas, United States     within an hour
#
#         host_response_rate  host_acceptance_rate  host_is_superhost  \
# 66632                  1.0                  0.93                  1
# 103516                 1.0                  1.00                  0
# 103532                 1.0                  1.00                  0
# 103533                 1.0                  1.00                  0
# 104081                 1.0                  1.00                  0
# 142106                 1.0                  1.00                  0
# 142108                 1.0                  1.00                  0
# 150465                 NaN                   NaN                  0
# 150467                 NaN                   NaN                  0
# 150548                 NaN                   NaN                  0
# 150549                 NaN                   NaN                  0
# 150550                 NaN                   NaN                  0
# 150552                 NaN                   NaN                  0
# 151313                 NaN                   NaN                  0
# 158933                 1.0                  0.97                  1
# 164064                 NaN                   NaN                  0
# 164616                 NaN                   NaN                  0
# 164617                 NaN                   NaN                  0
# 164618                 NaN                   NaN                  0
# 166634                 1.0                  0.97                  1
# 166635                 1.0                  0.97                  1
# 173793                 1.0                  1.00                  0
# 173807                 1.0                  1.00                  0
# 173812                 1.0                  1.00                  0
# 173817                 1.0                  1.00                  0
# 202196                 1.0                  1.00                  0
# 203497                 1.0                  0.84                  0
#
#         host_total_listings_count  host_has_profile_pic  \
# 66632                         5.0                     1
# 103516                        9.0                     1
# 103532                        9.0                     1
# 103533                        9.0                     1
# 104081                        9.0                     1
# 142106                        0.0                     1
# 142108                        0.0                     1
# 150465                        7.0                     1
# 150467                        7.0                     1
# 150548                        4.0                     1
# 150549                        4.0                     1
# 150550                        4.0                     1
# 150552                        4.0                     1
# 151313                        4.0                     1
# 158933                        5.0                     1
# 164064                        0.0                     1
# 164616                        7.0                     1
# 164617                        7.0                     1
# 164618                        7.0                     1
# 166634                        5.0                     1
# 166635                        5.0                     1
# 173793                     1813.0                     1
# 173807                     1813.0                     1
# 173812                     1813.0                     1
# 173817                     1813.0                     1
# 202196                     1813.0                     1
# 203497                     1515.0                     1
#
#         host_identity_verified  ... maximum_nights review_scores_rating  \
# 66632                        1  ...           1125                  NaN
# 103516                       1  ...           1125                  NaN
# 103532                       1  ...           1125                  NaN
# 103533                       1  ...           1125                  NaN
# 104081                       1  ...           1125                  NaN
# 142106                       1  ...           1125                  NaN
# 142108                       1  ...           1125                  NaN
# 150465                       1  ...           1125                  NaN
# 150467                       1  ...           1125                  NaN
# 150548                       1  ...           1125                  NaN
# 150549                       1  ...           1125                  NaN
# 150550                       1  ...           1125                  NaN
# 150552                       1  ...           1125                  NaN
# 151313                       1  ...           1125                  NaN
# 158933                       1  ...              7                  NaN
# 164064                       1  ...             28                  NaN
# 164616                       0  ...             30                  NaN
# 164617                       0  ...             30                  NaN
# 164618                       0  ...             30                  NaN
# 166634                       1  ...              7                  NaN
# 166635                       1  ...              7                  NaN
# 173793                       1  ...            365                  NaN
# 173807                       1  ...            365                  NaN
# 173812                       1  ...            365                  NaN
# 173817                       1  ...            365                  NaN
# 202196                       1  ...            365                  NaN
# 203497                       1  ...            365                  NaN
#
#         review_scores_accuracy  review_scores_cleanliness  \
# 66632                      NaN                        NaN
# 103516                     NaN                        NaN
# 103532                     NaN                        NaN
# 103533                     NaN                        NaN
# 104081                     NaN                        NaN
# 142106                     NaN                        NaN
# 142108                     NaN                        NaN
# 150465                     NaN                        NaN
# 150467                     NaN                        NaN
# 150548                     NaN                        NaN
# 150549                     NaN                        NaN
# 150550                     NaN                        NaN
# 150552                     NaN                        NaN
# 151313                     NaN                        NaN
# 158933                     NaN                        NaN
# 164064                     NaN                        NaN
# 164616                     NaN                        NaN
# 164617                     NaN                        NaN
# 164618                     NaN                        NaN
# 166634                     NaN                        NaN
# 166635                     NaN                        NaN
# 173793                     NaN                        NaN
# 173807                     NaN                        NaN
# 173812                     NaN                        NaN
# 173817                     NaN                        NaN
# 202196                     NaN                        NaN
# 203497                     NaN                        NaN
#
#        review_scores_checkin review_scores_communication  \
# 66632                    NaN                         NaN
# 103516                   NaN                         NaN
# 103532                   NaN                         NaN
# 103533                   NaN                         NaN
# 104081                   NaN                         NaN
# 142106                   NaN                         NaN
# 142108                   NaN                         NaN
# 150465                   NaN                         NaN
# 150467                   NaN                         NaN
# 150548                   NaN                         NaN
# 150549                   NaN                         NaN
# 150550                   NaN                         NaN
# 150552                   NaN                         NaN
# 151313                   NaN                         NaN
# 158933                   NaN                         NaN
# 164064                   NaN                         NaN
# 164616                   NaN                         NaN
# 164617                   NaN                         NaN
# 164618                   NaN                         NaN
# 166634                   NaN                         NaN
# 166635                   NaN                         NaN
# 173793                   NaN                         NaN
# 173807                   NaN                         NaN
# 173812                   NaN                         NaN
# 173817                   NaN                         NaN
# 202196                   NaN                         NaN
# 203497                   NaN                         NaN
#
#         review_scores_location  review_scores_value instant_bookable  \
# 66632                      NaN                  NaN                0
# 103516                     NaN                  NaN                1
# 103532                     NaN                  NaN                1
# 103533                     NaN                  NaN                1
# 104081                     NaN                  NaN                1
# 142106                     NaN                  NaN                1
# 142108                     NaN                  NaN                1
# 150465                     NaN                  NaN                0
# 150467                     NaN                  NaN                0
# 150548                     NaN                  NaN                1
# 150549                     NaN                  NaN                1
# 150550                     NaN                  NaN                1
# 150552                     NaN                  NaN                1
# 151313                     NaN                  NaN                1
# 158933                     NaN                  NaN                0
# 164064                     NaN                  NaN                0
# 164616                     NaN                  NaN                1
# 164617                     NaN                  NaN                1
# 164618                     NaN                  NaN                1
# 166634                     NaN                  NaN                0
# 166635                     NaN                  NaN                0
# 173793                     NaN                  NaN                1
# 173807                     NaN                  NaN                1
# 173812                     NaN                  NaN                1
# 173817                     NaN                  NaN                1
# 202196                     NaN                  NaN                1
# 203497                     NaN                  NaN                1
#
#         price_CNY
# 66632      303.40
# 103516     120.75
# 103532     136.85
# 103533     120.75
# 104081     103.60
# 142106      70.00
# 142108      70.00
# 150465     999.24
# 150467     999.24
# 150548    2271.00
# 150549    2271.00
# 150550    2271.00
# 150552    2271.00
# 151313    2271.00
# 158933     125.30
# 164064     323.00
# 164616    1135.50
# 164617    1135.50
# 164618    1135.50
# 166634     109.90
# 166635     109.90
# 173793    1381.68
# 173807    1388.52
# 173812    1333.80
# 173817    1381.68
# 202196    2311.92
# 203497    1135.44
#
# [27 rows x 31 columns]

# %%
# 删除重复数据
raw_data.drop_duplicates(keep=False, inplace=True)

# %%
#根据z-score去除极端值
z_score=(raw_data['price_CNY']-raw_data['price_CNY'].mean())/raw_data['price_CNY'].std()
outlier=z_score.abs() > 1.96
raw_data=raw_data[outlier == False]
data=raw_data

# %% [markdown]
# ## 数据清理完成，进行数据可视化

# %%
# 将数据分为训练集与测试集
X=
Y=data['price_CNY']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=111)
display(ex_rate[city])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
airbnb_tr.hist(bins = 20, figsize=(20,15))
plt.style.use('seaborn-whitegrid')
plt.show()

# %% [markdown]
# # Linear Models

# %%
airbnb_tr['price'].describe()

# %%
Linear

# %%
Lassco

# %%
Ridge

# %%
ElasticNet

# %% [markdown]
# ###  6 folds cross validation model performance
